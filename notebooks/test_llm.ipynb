# %%
from career_pilot.core.llm import CareerPilotLLM

# %%
llm = CareerPilotLLM()
response = llm.invoke("What is 1+1?")
print(f"Invoke: {response.content}")
print("Stream: ", end="")
for chunk in llm.stream("Count to 2"):
    print(chunk.content, end="", flush=True)
print()
